# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/car-evaluation-data-set/car_evaluation.csv

# %%
import numpy as np#linear algebra
import pandas as pd#data processing csv file i/o
import matplotlib.pyplot as plt#data valuation
import seaborn as sns#statistical data valuation
# %matplotlib inline

# %%
# !pip install category_encoders
# !pip install graphviz
# Out:
# Requirement already satisfied: category_encoders in /opt/conda/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (2.2.1)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.9.0->category_encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.3->statsmodels>=0.9.0->category_encoders) (3.1.1)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (0.20.3)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import category_encoders as ce
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import graphviz
from sklearn import tree

import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
data = '/kaggle/input/car-evaluation-data-set/car_evaluation.csv'
df = pd.read_csv(data)
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
col_names = ['buying','maint','doors','persons','lug_boot','safety','class']
df.columns = col_names
col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
#data processing and eda

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   object
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.shape
# Out:
# (1727, 7)

# %%
col_names = ['buying','maint','doors','persons','lug_boot','safety','class']
for col in col_names:
    print(col)
    print(df[col].unique())
    print(df[col].value_counts())
# Out:
# buying
# ['vhigh' 'high' 'med' 'low']
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# ['vhigh' 'high' 'med' 'low']
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# ['2' '3' '4' '5more']
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# ['2' '4' 'more']
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# ['small' 'med' 'big']
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# ['med' 'high' 'low']
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# ['unacc' 'acc' 'vgood' 'good']
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %% [markdown]
#  class balanced or not

# %%
df['class'].value_counts().plot(kind = "pie",autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# class is imbalanced need to balance

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
x = df.drop(['class'],axis=1)
y = df['class']

# %% [markdown]
# encoding data

# %%
encoder = ce.OrdinalEncoder(cols=['buying','maint','doors','persons','lug_boot','safety'])
x_en = encoder.fit_transform(x)

# %%
le = LabelEncoder()
y_en = le.fit_transform(y)

# %% [markdown]
# split the data into traning and testing

# %%
x_train,x_test,y_train,y_test = train_test_split(x_en,y_en,test_size = 0.33,random_state=42)

# %% [markdown]
# model traning

# %%
#instance the decisiontreeclassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini',max_depth=3, random_state=0)
#fit the model
clf_gini.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
from sklearn.metrics import accuracy_score
y_pred_gini = clf_gini.predict(x_test)
print("model accuracy score with ceiterion gini index:{0:0.4f}".format(accuracy_score(y_test,y_pred_gini)))
# Out:
# model accuracy score with ceiterion gini index:0.8053

# %%
cm = confusion_matrix(y_test, y_pred_gini)
print('confusion matrix\n\n',cm)
# Out:
# confusion matrix
#
#  [[ 71   0  56   0]
#  [ 18   0   0   0]
#  [ 11   0 388   0]
#  [ 26   0   0   0]]

# %%
classes_name = le.classes_.tolist()
classes_name
# Out:
# ['acc', 'good', 'unacc', 'vgood']

# %%
cm_df=pd.DataFrame(cm,index=classes_name,columns = classes_name)
cm_df
# Out:
#        acc  good  unacc  vgood
# acc     71     0     56      0
# good    18     0      0      0
# unacc   11     0    388      0
# vgood   26     0      0      0

# %%
sns.heatmap(cm_df,annot=True,fmt='d',cmap='YlGnBu')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       127
#            1       0.00      0.00      0.00        18
#            2       0.87      0.97      0.92       399
#            3       0.00      0.00      0.00        26
#
#     accuracy                           0.81       570
#    macro avg       0.36      0.38      0.37       570
# weighted avg       0.74      0.81      0.77       570
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import imblearn
from imblearn.under_sampling import RandomUnderSampler
x = df.drop(['class'],axis=1)
y = df['class']
ran=RandomUnderSampler()
x_rs,y_RandomOverSamplerrs = ran.fit_resample(x,y)

# %%
encoder = ce.OrdinalEncoder(cols=['buying','maint','doors','persons','lug_boot','safety'])
x_en = encoder.fit_transform(x_rs)

# %%
encoder = ce.OrdinalEncoder(cols=['buying','maint','doors','persons','lug_boot','safety'])
x_en = encoder.fit_transform(x_rs)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_en,y_en,test_size = 0.33,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x_en,y_en,test_size = 0.33,random_state=42)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:443, in indexable(*iterables)
#     424 """Make arrays indexable for cross-validation.
#     425
#     426 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     439     sparse matrix, or dataframe) or `None`.
#     440 """
#     442 result = [_make_indexable(X) for X in iterables]
# --> 443 check_consistent_length(*result)
#     444 return result
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [260, 1727]

# %%
#instance the decisiontreeclassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini',max_depth=3, random_state=0)
#fit the model
clf_gini.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score
y_pred_gini = clf_gini.predict(x_test)
print("model accuracy score with ceiterion gini index:{0:0.4f}".format(accuracy_score(y_test,y_pred_gini)))

# %%
cm = confusion_matrix(y_test, y_pred_gini)
print('confusion matrix\n\n',cm)

# %%
sns.heatmap(cm_df,annot=True,fmt='d',cmap='YlGnBu')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred_gini))

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
x = df.drop(['class'],axis=1)
y = df['class']
ran=RandomOverSampler()
x_rs,y_rs = ran.fit_resample(x,y)

# %%
encoder = ce.OrdinalEncoder(cols=['buying','maint','doors','persons','lug_boot','safety'])
x_en = encoder.fit_transform(x_rs)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_en,y_en,test_size = 0.33,random_state=42)

# %%
#instance the decisiontreeclassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini',max_depth=3, random_state=0)
#fit the model
clf_gini.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score
y_pred_gini = clf_gini.predict(x_test)
print("model accuracy score with ceiterion gini index:{0:0.4f}".format(accuracy_score(y_test,y_pred_gini)))
# Out:
# model accuracy score with ceiterion gini index:0.6869

# %%
cm = confusion_matrix(y_test, y_pred_gini)
print('confusion matrix\n\n',cm)
# Out:
# confusion matrix
#
#  [[120 118  36  65]
#  [  0 217   0 172]
#  [ 11   2 224  25]
#  [  0   0   0 380]]

# %%
cm_df=pd.DataFrame(cm,index=classes_name,columns = classes_name)
cm_df
# Out:
#        acc  good  unacc  vgood
# acc    120   118     36     65
# good     0   217      0    172
# unacc   11     2    224     25
# vgood    0     0      0    380

# %%
sns.heatmap(cm_df,annot=True,fmt='d',cmap='YlGnBu')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.35      0.51       339
#            1       0.64      0.56      0.60       389
#            2       0.86      0.85      0.86       262
#            3       0.59      1.00      0.74       380
#
#     accuracy                           0.69      1370
#    macro avg       0.75      0.69      0.68      1370
# weighted avg       0.74      0.69      0.67      1370

# %%
from imblearn.combine import SMOTEENN
x = df.drop(['class'],axis=1)
y = df['class']
encoder =ce.OrdinalEncoder(cols=['buying','maint','doors','persons','lug_boot','safety'])
x_en = encoder.fit_transform(x)
le = LabelEncoder()
y_en = le.fit_transform(y)

ran=SMOTEENN()
x_rs,y_rs=ran.fit_resample(x_en,y_en)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_rs,y_rs,test_size = 0.33,random_state=42)

# %%
#instance the decisiontreeclassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini',max_depth=3, random_state=0)
#fit the model
clf_gini.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_gini = clf_gini.predict(x_test)
print("model accuracy score with ceiterion gini index:{0:0.4f}".format(accuracy_score(y_test,y_pred_gini)))
# Out:
# model accuracy score with ceiterion gini index:0.6869

# %%
cm = confusion_matrix(y_test, y_pred_gini)
print('confusion matrix\n\n',cm)
# Out:
# confusion matrix
#
#  [[120 118  36  65]
#  [  0 217   0 172]
#  [ 11   2 224  25]
#  [  0   0   0 380]]

# %%
cm_df=pd.DataFrame(cm,index=classes_name,columns = classes_name)
cm_df
# Out:
#        acc  good  unacc  vgood
# acc    120   118     36     65
# good     0   217      0    172
# unacc   11     2    224     25
# vgood    0     0      0    380

# %%
sns.heatmap(cm_df,annot=True,fmt='d',cmap='YlGnBu')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.35      0.51       339
#            1       0.64      0.56      0.60       389
#            2       0.86      0.85      0.86       262
#            3       0.59      1.00      0.74       380
#
#     accuracy                           0.69      1370
#    macro avg       0.75      0.69      0.68      1370
# weighted avg       0.74      0.69      0.67      1370

# %%
plt.figure(figsize=(12,8))
from sklearn import tree
tree.plot_tree(clf_gini.fit(x_train,y_train))
# Out:
# [Text(0.375, 0.875, 'x[3] <= 1.5\ngini = 0.746\nsamples = 2781\nvalue = [634, 757, 586, 804]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 332\nvalue = [0, 0, 332, 0]'),
#  Text(0.5, 0.625, 'x[0] <= 2.5\ngini = 0.719\nsamples = 2449\nvalue = [634, 757, 254, 804]'),
#  Text(0.25, 0.375, 'x[1] <= 2.5\ngini = 0.462\nsamples = 531\nvalue = [339, 0, 192, 0]'),
#  Text(0.125, 0.125, 'gini = 0.411\nsamples = 218\nvalue = [63, 0, 155, 0]'),
#  Text(0.375, 0.125, 'gini = 0.208\nsamples = 313\nvalue = [276, 0, 37, 0]'),
#  Text(0.75, 0.375, 'x[5] <= 1.5\ngini = 0.644\nsamples = 1918\nvalue = [295, 757, 62, 804]'),
#  Text(0.625, 0.125, 'gini = 0.425\nsamples = 654\nvalue = [185, 460, 9, 0]'),
#  Text(0.875, 0.125, 'gini = 0.531\nsamples = 1264\nvalue = [110, 297, 53, 804]')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini,out_file=None,feature_names=x_train.columns,class_names=classes_name,filled=True,rounded=True,special_characters=True)
graph = graphviz.Source(dot_data)

# %%
from sklearn.model_selection import GridSearchCV


params = {'max_depth': [2, 3, 5, 6,8,10, 20], 'min_samples_leaf': [5, 10, 20, 50, 100], 'criterion': ["gini", "entropy"] }

# %%
grid_search = GridSearchCV(estimator=clf_gini,param_grid=params,cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 70 candidates, totalling 280 fits
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(max_depth=3, random_state=0),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 6, 8, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
best_par = grid_search.best_estimator_

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy:",accuracy_score(y_train, dt_classifier.predict(x_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(x_train)))
     print("-"*50)
    print("Test Accuracy:",accuracy_score(y_test, dt_classifier.predict(x_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(x_test)))
    
    cm_df = pd.DataFrame(cm, index = classes_name,columns = classes_name)
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='YlGnBu')
    print(classification_report(y_test, dt_classifier.predict(x_test)))

# %%
evaluate_model(best_par)
# Out:
# Train Accuracy: 0.9913700107874865
# Train Confusion Matrix:
# [[620  10   3   1]
#  [  0 757   0   0]
#  [ 10   0 576   0]
#  [  0   0   0 804]]
# --------------------------------------------------
# Test Accuracy: 0.9824817518248176
# Test Confusion Matrix:
# [[323  11   5   0]
#  [  3 386   0   0]
#  [  5   0 257   0]
#  [  0   0   0 380]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       339
#            1       0.97      0.99      0.98       389
#            2       0.98      0.98      0.98       262
#            3       1.00      1.00      1.00       380
#
#     accuracy                           0.98      1370
#    macro avg       0.98      0.98      0.98      1370
# weighted avg       0.98      0.98      0.98      1370

# %%
best_par.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20, min_samples_leaf=5,
#                        random_state=0)

# %%
print("Test Accuracy:",accuracy_score(y_test, best_par.predict(x_test)))
# Out:
# Test Accuracy: 0.9824817518248176

# %%
import joblib
filename = 'finalized_model.joblib'
joblib.dump(best_par,filename)
# Out:
# ['finalized_model.joblib']

# %%
from IPython.display import FileLink
FileLink(r'finalized_model.joblib')
# Out:
# /kaggle/working/finalized_model.joblib
